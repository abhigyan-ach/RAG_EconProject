# %%
# !pip install -qU \
  transformers==4.31.0 \
  sentence-transformers==2.2.2 \
  pinecone-client==2.2.2 \
  datasets==2.14.0 \
  accelerate==0.21.0 \
  einops==0.6.1 \
  langchain==0.0.240 \
  xformers==0.0.20 \
  bitsandbytes==0.41.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.2/492.2 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 50.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from torch import cuda
from langchain.embeddings.huggingface import HuggingFaceEmbeddings

embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

embed_model = HuggingFaceEmbeddings(
    model_name=embed_model_id,
    model_kwargs={'device': device},
    encode_kwargs={'device': device, 'batch_size': 32}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
docs = [
    "this is one document",
    "and another document"
]

embeddings = embed_model.embed_documents(docs)

print(f"We have {len(embeddings)} doc embeddings, each with "
      f"a dimensionality of {len(embeddings[0])}.")
# Out:
# We have 2 doc embeddings, each with a dimensionality of 384.

# %%
import pandas as pd

with open("/content/sample_data/path.txt", "r") as f:
    content = f.read()

df=pd.read_excel(content)
df.head()
df.columns
# df["ExternalReference"].nunique
# col=['CPIPrediction','CPIJustification','JobPrediction','JoblessJustification', 'EDU']
# essentials=df[['CPIPrediction','CPIJustification','JobPrediction','JoblessJustification', 'EDU']].copy()
# essentials.drop([0])
# essentials.head()
# #essentia
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'ProlificID', 'CPIPrediction',
#        'CPIJustification', 'TimeDelay_First Click', 'TimeDelay_Last Click',
#        'TimeDelay_Page Submit', 'TimeDelay_Click Count', 'JobPrediction',
#        'JoblessJustification', 'TimeDelay_First Click.1',
#        'TimeDelay_Last Click.1', 'TimeDelay_Page Submit.1',
#        'TimeDelay_Click Count.1', 'EDU'],
#       dtype='object')

# %%
essentials=df[['CPIPrediction','CPIJustification','JobPrediction','JoblessJustification', 'EDU']]
essentials.head()
#essentia
# Out:
#                                        CPIPrediction  \
# 0  Inflation occurs when the price of goods and s...
# 1                                                3.6
# 2                                                  2
# 3                                                  4
# 4                                                0.5
#
#                                     CPIJustification  \
# 0  Please write down 3-5 sentences to justify you...
# 1  I believe we will see a continued cooling of i...
# 2  I think inflation will go up slightly thanks t...
# 3  I was following the trend, and that seemed lik...
# 4          It is still going in an upward projection
#
#                                        JobPrediction  \
# 0  Total nonfarm payroll measures employment in t...
# 1                                             210000
# 2                                             220000
# 3                                             210000
# ...

# %%
essentials = essentials.drop(essentials.index[0])

# Display the DataFrame after dropping the 0th row
print("\nDataFrame after dropping the 0th row:")
essentials.head()
# Out:
# DataFrame after dropping the 0th row:
#   CPIPrediction                                   CPIJustification  \
# 1           3.6  I believe we will see a continued cooling of i...
# 2             2  I think inflation will go up slightly thanks t...
# 3             4  I was following the trend, and that seemed lik...
# 4           0.5          It is still going in an upward projection
# 5           4.1  The economy is still the same but doesn't get ...
#
#   JobPrediction                               JoblessJustification  \
# 1        210000  I believe we will continue to see an improveme...
# 2        220000   I think the number of jobless claims will go up.
# 3        210000  It falls in line with the graph, and it's simi...
# 4        215000             It may be going down but not by a lot.
# 5        209000  The trend  is going down so I expect the numbe...
#
#                                                  EDU
# 1  Graduate or professional degree (MA, MS, MBA, ...
# ...

# %%
docs=[]
print(len(essentials))
for i in range(1,len(essentials)):
    d="My CPI Prediction i " + str(essentials.CPIPrediction[i])+". I think so because " + essentials.CPIJustification[i] +". My Jobs Prediction is "+ str(essentials.JobPrediction[i])+". I think so because "+ essentials.JoblessJustification[i]+"."+" My education is "+ essentials.EDU[i]+"\n"
    docs.append(d)

# for i in docs:
#   print(i)

embeddings = embed_model.embed_documents(docs)

print(f"We have {len(embeddings)} doc embeddings, each with "
      f"a dimensionality of {len(embeddings[0])}.")
# Out:
# 21
# We have 20 doc embeddings, each with a dimensionality of 384.

# %%
import os
import pinecone
#os.environ.get('PINECONE_API_KEY') or
# get API key from app.pinecone.io and environment from console
pinecone.init(
    api_key='35ff28eb-f787-4950-8d45-70e26d9a71fd',
    environment=os.environ.get('PINECONE_ENVIRONMENT') or 'gcp-starter'
)

# %%
import time

index_name = 'llama-2-rag'

if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        index_name,
        dimension=len(embeddings[0]),
        metric='cosine'
    )
    # wait for index to finish initialization
    while not pinecone.describe_index(index_name).status['ready']:
        time.sleep(1)

# %%
index = pinecone.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0486,
#  'namespaces': {'': {'vector_count': 4860}},
#  'total_vector_count': 4860}

# %%
from datasets import load_dataset

data = load_dataset(
    'jamescalam/llama-2-arxiv-papers-chunked',
    split='train'
)
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
docs_df=pd.DataFrame(docs)
batch_size = 1
# Add a new column 'id' filled with the index of each row
docs_df
docs_df['id'] = docs_df.reset_index().index
docs_df = docs_df.rename(columns={0: 'Text'})
docs_df = pd.concat([docs_df, essentials['EDU']], axis=1)
docs_df['EDU'] = docs_df['EDU'].fillna("Prefer not to say")
docs_df['Text'] = docs_df['Text'].fillna("Prefer not to say")
docs_df['id'] = docs_df['id'].fillna("0")

docs_df.head()
docs_df.columns

for i in range(0, len(docs_df), batch_size):
      i_end = min(len(data), i+batch_size)
      batch = docs_df.iloc[i:i_end]
      ids = [f"{x['id']}" for i, x in batch.iterrows()]
      texts = [str(x['Text']) for i, x in batch.iterrows()]
      # print(type(texts))
      # print("This is an example text:\n",texts,"\n")
      embeds = embed_model.embed_documents(texts)
      # get metadata to store in Pinecone
      metadata = [
          {'text': x['Text'],
          'id': x['id']} for i, x in batch.iterrows()
      ]
      # add to Pinecone
      index.upsert(vectors=zip(ids, embeds, metadata))

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0486,
#  'namespaces': {'': {'vector_count': 4860}},
#  'total_vector_count': 4860}

# %%
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-13b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, need auth token for these
hf_auth = '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'
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)
model.eval()
print(f"Model loaded on {device}")
# Out:
# config.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Model loaded on cuda:0

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
generate_text = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    return_full_text=True,  # langchain expects the full text
    task='text-generation',
    # we pass model parameters here too
    temperature=0.0,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=512,  # mex number of tokens to generate in the output
    repetition_penalty=1.1  # without this output begins repeating
)

# %%
res = generate_text("Explain to me the meaning of CPI.")
print(res[0]["generated_text"])
# Out:
# Explain to me the meaning of CPI.
# CPI stands for Consumer Price Index, which is a measure of the average change in prices of a basket of goods and services that are commonly consumed by households. It is calculated by the Bureau of Labor Statistics (BLS) and is widely used as an indicator of inflation.
# The CPI measures the price changes of a fixed basket of goods and services over time, providing a comprehensive view of the rate of inflation. The basket of goods and services includes items such as food, housing, transportation, clothing, and healthcare. The CPI is calculated using a formula that takes into account the weights of each item in the basket, based on their importance to household consumption expenditures.
# ...

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# %%
llm(prompt="Explain to me the difference between Micro and Macro Economics.")
# Out:
# '\n\nMicroeconomics is the study of individual economic units such as households, firms, and markets. It focuses on understanding the behavior and decision-making processes of these units, and how they interact with each other in the market. Microeconomics examines the supply and demand for specific goods and services, and how prices are determined in a market economy. It also studies the various factors that affect consumer behavior and firm decision-making, such as income, preferences, technology, and government policies.\n\nMacroeconomics, on the other hand, is the study of the entire economy as a whole. It looks at the overall performance of the economy, including issues such as inflation, unemployment, and economic growth. Macroeconomics examines the relationships between different sectors of the economy, such as households, firms, and governments, and how they interact with each other. It also studies the impact of various economic policies, such as monetary and fiscal policy, 
# ...

# %%
from langchain.vectorstores import Pinecone

text_field = 'text'  # field in metadata that contains text content

vectorstore = Pinecone(
    index, embed_model.embed_query, text_field
)

# %%
query = 'What makes CPI special'
#Just a similarity search: doesn't actually use the LLM
vectorstore.similarity_search(
    query,  # the search query
    k=3  # returns top 3 most relevant chunks of text
)
# Out:
# [Document(page_content='My CPI Prediction i 4.3. I think so because Observation  based on rising oil prices lately. Also, the CPI has been manipulated by every presidential administration dating back to Carter. One aspect of the "basket of goods" coming in too hot? Substitute something that\'s stable or dropping in price instead. The CPI is tied to Social Security payouts, so there is a reason they cheat with this data. \n\nInflation is ALWAYS higher than reported. But the phony headline number can only be massaged so much, so I picked 4.3% (it\'s actually more like 7-8% in reality). The basket of goods sometimes will have electronics or phones instead of things people really need like gasoline or meat. A total farce, just like our government. Shadow Stats by John Williams has been tracking the unsubstituted number for years now. He understands the game. \n\nI\'m a former Wall St. worker. I\'ve seen this first hand. An old WS saw goes, "don\'t believe the rumor until you hear an offi
# ...

# %%
from langchain.chains import RetrievalQA

rag_pipeline = RetrievalQA.from_chain_type(
    llm=llm, chain_type='stuff',
    retriever=vectorstore.as_retriever()
)

# %%
import time

start=time.time()
rag_pipeline('what is the overall consensus on Joblessness claims?')
end=time.time()

# # torch.cuda.memory_summary(device=None, abbreviated=False)
# import torch
# torch.cuda.empty_cache()

# %%
print("Time for a prompt response: ",end-start)

# %%
rag_pipeline('what is the overall consensus on Joblessness claims?')
# Out:
# {'query': 'what is the overall consensus on Joblessness claims?',
#  'result': ' According to the Bureau of Labor Statistics, the seasonally adjusted number of initial claims was 217,000 for the week ending August 29th. This represents a decrease of 1,000 from the previous week. The four-week moving average was 220,750, a decrease of 2,750 from the previous week. These numbers suggest that the labor market remains strong and that the economy is continuing to recover from the COVID-19 pandemic. However, it is important to note that the number of continuing claims, which measures the number of people who have been receiving benefits for more than a week, increased by 11,000 to 1.7 million for the week ending August 22nd. This suggests that while the labor market is improving, there are still many people who are struggling to find employment.'}
